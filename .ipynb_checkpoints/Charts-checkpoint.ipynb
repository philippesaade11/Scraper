# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dirt = 'test-depth-5/'
points = 199

# %%
dirt = 'test-depth-5-fixurl/'
points = 199

# %%
dirt = 'test-depth-5-long/'
points = 2400

# %%
dirt = 'test-depth-5-long-2/'
points = 3900

# %%
dirt = 'test-depth-5-memetype/'
points = 199

# %%
dirt = 'test-html/'
points = 2218

# %%
dirt = 'test-pdf/'
points = 12

# %%
data = pd.read_csv(dirt+'pdf_benchmark.csv', sep=',', header=0, names=['type', 'start', 'end', 'name', 'url'])
data['time'] = data['end'] - data['start']
data = data.sort_values('start')
extract_table = data[data['type'] == 'extract table']
extract_image = data[data['type'] == 'image table']
extract_sentence = data[data['type'] == 'sentence table']
extract_list = data[data['type'] == 'list table']
sort_time = data[data['type'] == 'sort table']
pdf_open = data[data['type'] == 'open pdf']
url_open = data[data['type'] == 'open url']
duration_tables = [url_open, pdf_open, sort_time, extract_list, extract_sentence, extract_image, extract_table]

# %%
total = pd.read_csv(dirt+'main_benchmark.csv', sep=',', header=0, names=['type', 'start', 'end', 'url', 'depth'])
total['time'] = total['end'] - total['start']
total = total.sort_values('start')
total
# Out:
#             type         start           end  \
# 0   open iframes  1.674921e+09  1.674921e+09
# 1   open iframes  1.674921e+09  1.674921e+09
# 2   open iframes  1.674921e+09  1.674921e+09
# 3   open iframes  1.674921e+09  1.674921e+09
# 4   open iframes  1.674921e+09  1.674921e+09
# 5   open iframes  1.674921e+09  1.674921e+09
# 6   open iframes  1.674921e+09  1.674921e+09
# 7   open iframes  1.674921e+09  1.674921e+09
# 8   open iframes  1.674921e+09  1.674921e+09
# 9   open iframes  1.674921e+09  1.674921e+09
# 10  open iframes  1.674921e+09  1.674921e+09
# 11  open iframes  1.674921e+09  1.674921e+09
# 12  open iframes  1.674921e+09  1.674921e+09
#
#                                                   url  depth       time
# 0   https://www.pdfscripting.com/public/FreeStuff/...      1   1.218676
# 1   https://www.pdfscripting.com/public/FreeStuff/...      1   1.496538
# 2   https://www.pdfscripting.com/public/FreeStuff/...      1   1.246456
# ...

# %%
cpumem = pd.read_csv(dirt+'output.csv', sep=',', header=0, names=['id', 'name', 'cpu%', 'mem usage', 'mem%', 'net io', 'block', 'pid', 'start'])
cpumem = cpumem.sort_values('start')
cpumem['name'] = cpumem['name'].str.split('-', expand=True)[1]
cpumem['cpu%'] = pd.to_numeric(cpumem['cpu%'].str.split('%', expand=True)[0])
cpumem['mem%'] = pd.to_numeric(cpumem['mem%'].str.split('%', expand=True)[0])
htmlcpumem = cpumem[cpumem['name'] == 'pdfparser']
maincpumem = cpumem[cpumem['name'] == 'main']
basecpumem = cpumem[cpumem['name'] == 'basichtmlparser']
basecpumem
# Out:
#                id             name  cpu%            mem usage  mem%  \
# 1    5e1997d934be  basichtmlparser  0.01  67.73MiB / 7.689GiB  0.86
# 7    5e1997d934be  basichtmlparser  0.01  67.73MiB / 7.689GiB  0.86
# 13   5e1997d934be  basichtmlparser  0.01  67.73MiB / 7.689GiB  0.86
# 19   5e1997d934be  basichtmlparser  0.01  67.73MiB / 7.689GiB  0.86
# 25   5e1997d934be  basichtmlparser  0.34  72.05MiB / 7.689GiB  0.92
# 31   5e1997d934be  basichtmlparser  0.01  72.05MiB / 7.689GiB  0.92
# 37   5e1997d934be  basichtmlparser  0.01  72.05MiB / 7.689GiB  0.92
# 43   5e1997d934be  basichtmlparser  0.01  72.05MiB / 7.689GiB  0.92
# 49   5e1997d934be  basichtmlparser  0.01  72.05MiB / 7.689GiB  0.92
# 55   5e1997d934be  basichtmlparser  0.01  72.05MiB / 7.689GiB  0.92
# 61   5e1997d934be  basichtmlparser  0.01  72.05MiB / 7.689GiB  0.92
# 67   5e1997d934be  basichtmlparser  0.01  72.05MiB / 7.689GiB  0.92
# 73   5e1997d934be  basichtmlparser  0.01  72.05MiB / 7.689GiB  0.92
# ...

# %%
time_tables = []
start_tables = []
for i in range(len(duration_tables)):
    time_tables.append(duration_tables[i]['time'].values[-points:])
    start_tables.append(duration_tables[i]['start'].values[-points:])
    
message_passing_time = total['time'].values[-points:] - sum(time_tables)
time_vals = total['start'].values[-points:]
content_length = total['url'].apply(lambda x: float(requests.head(x, allow_redirects=True).headers['Content-Length'])/1e6).values[-points:]

# %%
import requests

url_open_time = url_open['time'].values[-points:]
parse_html_time = open_iframes['parse time'].values[-points:]
fix_url_open_time = open_iframes['time'].values[-points:] - open_iframes['parse time'].values[-points:]
message_passing_time = total['time'].values[-points:] - parse_html_time - url_open_time - fix_url_open_time
time_vals = total['start'].values[-points:]
content_length = total['url'].apply(lambda x: float(requests.head(x, allow_redirects=True).headers['Content-Length'])/1e-6).values[-points:]

# %%
import re

htmlcpumem = htmlcpumem[(htmlcpumem['start'] >= time_vals.min())]# & (htmlcpumem['start'] <= time_vals.max())]
maincpumem = maincpumem[(maincpumem['start'] >= time_vals.min())]# & (maincpumem['start'] <= time_vals.max())]
basecpumem = basecpumem[(basecpumem['start'] >= time_vals.min())]# & (basecpumem['start'] <= time_vals.max())]
basecpumem['mem usage'] = basecpumem['mem usage'].apply(lambda x: float(re.sub('[^0-9.]', '', x.split('/')[0])))
maincpumem['mem usage'] = maincpumem['mem usage'].apply(lambda x: float(re.sub('[^0-9.]', '', x.split('/')[0])))
htmlcpumem['mem usage'] = htmlcpumem['mem usage'].apply(lambda x: float(re.sub('[^0-9.]', '', x.split('/')[0])))
time_cpu_vals = htmlcpumem['start']
htmlcpu_vals = htmlcpumem['cpu%']
htmlmem_vals = htmlcpumem['mem usage']
maincpu_vals = maincpumem['cpu%']
mainmem_vals = maincpumem['mem usage']
basecpu_vals = basecpumem['cpu%']
basemem_vals = basecpumem['mem usage']
# Out:
# C:\Users\96181\AppData\Local\Temp\ipykernel_16416\353142743.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basecpumem['mem usage'] = basecpumem['mem usage'].apply(lambda x: float(re.sub('[^0-9.]', '', x.split('/')[0])))

# %%
N = 50
url_open_time = np.convolve(url_open_time, np.ones(N)/N, mode='valid')
parse_html_time = np.convolve(parse_html_time, np.ones(N)/N, mode='valid')
fix_url_open_time = np.convolve(fix_url_open_time, np.ones(N)/N, mode='valid')
message_passing_time = np.convolve(message_passing_time, np.ones(N)/N, mode='valid')
time_vals = np.convolve(time_vals, np.ones(N)/N, mode='valid')

# %%
N = 100
time_cpu_vals = np.convolve(time_cpu_vals, np.ones(N)/N, mode='valid')
htmlcpu_vals = np.convolve(htmlcpu_vals, np.ones(N)/N, mode='valid')
htmlmem_vals = np.convolve(htmlmem_vals, np.ones(N)/N, mode='valid')
maincpu_vals = np.convolve(maincpu_vals, np.ones(N)/N, mode='valid')
mainmem_vals = np.convolve(mainmem_vals, np.ones(N)/N, mode='valid')
basecpu_vals = np.convolve(basecpu_vals, np.ones(N)/N, mode='valid')
basemem_vals = np.convolve(basemem_vals, np.ones(N)/N, mode='valid')

# %%
start_time = min(time_vals)
time_vals = (time_vals - start_time) / 60
time_cpu_vals = (time_cpu_vals - start_time) / 60
start_tables = [(t - start_time) / 60 for t in start_tables]

# %%
plt.stackplot(time_vals,
              [url_open_time, parse_html_time, fix_url_open_time, message_passing_time],
              labels=['Url open', 'HTML Parse', 'URL Clean', 'Crawler'])
plt.ylabel('Time')
plt.legend()

plt2 = plt.twinx()
plt2.plot(time_cpu_vals, htmlcpu_vals, color='black')
plt2.plot(time_cpu_vals, htmlmem_vals, color='black', linestyle='dashed')
plt2.plot(time_cpu_vals, maincpu_vals, color='red')
plt2.plot(time_cpu_vals, mainmem_vals, color='red', linestyle='dashed')
plt2.plot(time_cpu_vals, basecpu_vals, color='green')
plt2.plot(time_cpu_vals, basemem_vals, color='green', linestyle='dashed')
plt2.set_ylabel('CPU/MEM %')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16416\661179857.py in <cell line: 1>()
#       1 plt.stackplot(time_vals,
# ----> 2               [url_open_time, parse_html_time, fix_url_open_time, message_passing_time],
#       3               labels=['Url open', 'HTML Parse', 'URL Clean', 'Crawler'])
#       4 plt.ylabel('Time')
#       5 plt.legend()
#
# NameError: name 'url_open_time' is not defined

# %%
plt.stackplot(time_vals,
              [url_open_time, parse_html_time, fix_url_open_time, message_passing_time],
              labels=['Url open', 'HTML Parse', 'URL Clean', 'Crawler'])
plt.legend()
plt.show()

# %%
plt.stackplot(time_vals,
              [url_open_time, parse_html_time, fix_url_open_time, message_passing_time],
              labels=['Url open', 'HTML Parse', 'URL Clean', 'Crawler'])
plt.ylabel('Duration (seconds)')
plt.xlabel('Timestamp (hours)')
plt.legend()
plt.show()

# %%
plt.stackplot(time_vals,
              [url_open_time, parse_html_time, fix_url_open_time, message_passing_time],
              labels=['Url open', 'HTML Parse', 'URL Clean', 'Crawler'])
plt.legend()
plt.show()

# %%
plt.stackplot(time_vals,
              duration_tables,
#               [url_open_time, parse_html_time, fix_url_open_time, message_passing_time],
#               labels=['Url open', 'HTML Parse', 'URL Clean', 'Crawler'])
                labels=['Open URL', 'Load PDF', 'Sort', 'Extract Lists', 'Extract Sentences', 'Extract Images', 'Extract Tables'])
plt.ylabel('Duration (seconds)')
plt.xlabel('Timestamp (minutes)')
plt.title('Duration of parsing 12 PDF files')
plt.legend(loc='upper right')

plt2 = plt.twinx()
plt2.plot(time_vals, content_length, color='black', linestyle='dashed', label='Content Length')
plt2.set_ylabel('Content Length (MiB)')
x1,x2,y1,y2 = plt2.axis()
plt2.axis((x1,x2,y1,y2+5))
plt2.legend(loc='upper left')

plt.show()

# %%
labels=['Open URL', 'Load PDF', 'Sort', 'Extract Lists', 'Extract Sentences', 'Extract Images', 'Extract Tables'])

# %%
time_tables[1]
# Out:
# array([0.00340056, 0.00161648, 0.00323939, 0.00954318, 0.00356078,
#        0.12143588, 1.6114285 , 0.00490761, 0.00469494, 0.00317788,
#        0.00431347, 0.00390959])

# %%
plt.plot(time_cpu_vals, htmlcpu_vals, color='black', label='PDF Parser')
# plt.plot(time_cpu_vals, htmlmem_vals, color='black', linestyle='dashed', label='HTML Parser')
plt.plot(time_cpu_vals, maincpu_vals, color='red', label='Main Parser')
# plt.plot(time_cpu_vals, mainmem_vals, color='red', linestyle='dashed', label='Main Parser')
# plt.plot(time_cpu_vals, basecpu_vals, color='green', label='Basic HTML Parser')
# plt.plot(time_cpu_vals, basemem_vals, color='green', linestyle='dashed', label='Basic HTML Parser')
plt.ylabel('Memory (MiB)')
plt.xlabel('Timestamp (minutes)')
plt.title('Memory usage of the parsers over time')
plt.legend()

plt2 = plt.twinx()
plt2.scatter(start_tables[0]+(time_tables[0]/60), content_length, marker='->', color='red', label='Start of loading PDF')
plt2.scatter(start_tables[1]+(time_tables[1]/60), content_length, marker='|', color='blue', label='End of loading PDF')
plt2.set_ylabel('Content Length (MiB)')
x1,x2,y1,y2 = plt2.axis()
plt2.axis((x1,x2,y1,y2))
plt2.legend(loc='upper left')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\markers.py in _set_marker(self, marker)
#     358             try:
# --> 359                 Path(marker)
#     360                 self._marker_function = self._set_vertices
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     128         """
# --> 129         vertices = _to_unmasked_float_array(vertices)
#     130         _api.check_shape((None, 2), vertices=vertices)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _to_unmasked_float_array(x)
#    1368     else:
# -> 1369         return np.asarray(x, float)
#    1370
#
# ValueError: could not convert string to float: '|-'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
np.mean(message_passing_time), np.mean(fix_url_open_time)
# Out:
# (0.3394066546513484, 0.09453215990311062)

# %%
np.mean(message_passing_time), np.mean(fix_url_open_time)
# Out:
# (0.5545520723783054, 1.877426046469273)

# %%
plt.stackplot(time_vals,
              [url_open_time, parse_html_time, fix_url_open_time, message_passing_time],
              labels=['Url open', 'HTML Parse', 'URL Clean', 'Crawler'])
plt.legend()
plt.show()

# %%
import lxml.html as lxmlhtml

html = '''
<html lang="de" class=""><head> <base href="https://www.foerderdatenbank.de/"> <meta charset="UTF-8"> <title>Förderdatenbank - Fördersuche </title> <meta name="title" content=" Fördersuche "> <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.5, user-scalable=1"> <meta name="author" content="Bundesministerium für Wirtschaft und Klimaschutz, Referat Öffentlichkeitsarbeit"> <meta name="copyright" content="Bundesministerium für Wirtschaft und Klimaschutz"> <meta name="publisher" content="BMWK"> <meta name="google-site-verification" content="v-SPiTthBWFERCn1oFd6tREbbHbWP0Ca-ZIwmTPvD00"> <meta property="og:url" content="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?queryResultId=null&amp;pageNo=0&amp;submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport"> <meta property="og:title" content=" Fördersuche "> <script>window.onload=function(){var a=document.getElementsByClassName("no-js");a[0].classList.remove("no-js")};</script> <link rel="canonical" href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?queryResultId=null&amp;pageNo=0&amp;submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport"> <link rel="license" href="https://www.foerderdatenbank.de/FDB/DE/Meta/Impressum/impressum.html" type="text/html" title="Impressum"> <link rel="start" href="https://www.foerderdatenbank.de/FDB/DE/Home/home.html" type="text/html" title="HomepageSprungmarke"> <link rel="search" href="https://www.foerderdatenbank.de/FDB/DE/Service/Suche/suche.html" type="text/html" title="Suche"> <link rel="shortcut icon" href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Frontend/Images/favicon.ico?__blob=normal&amp;v=2" type="image/ico"> <link rel="stylesheet" href="https://www.foerderdatenbank.de/static/FDB/css/main.min.css" type="text/css"> <link rel="stylesheet" href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Frontend/Styles/additional.css?v=2" type="text/css"> <link rel="stylesheet" href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Frontend/Styles/maintenance.css?v=27" type="text/css"> <style>
.basket-session>.btn:nth-of-type(2) {
 margin-right: 2rem;
} 
    </style> <script>var et_pagename="DE%2FService%2FSuche%2Fsuche";var et_areas="FDB%2FDE%2FService%2FSuche%2F";var et_url="https%3A%2F%2Fwww.foerderdatenbank.de%2FFDB%2FDE%2FService%2FSuche%2Fsuche.html";var cc_attributes=new Object();cc_attributes.etcc_cu="onsite";cc_attributes.etcc_med_onsite="Interne Suche";cc_attributes.etcc_cmp_onsite="Mit Ergebnis";cc_attributes.etcc_st_onsite="";</script> <script id="_etLoader" data-block-cookies="true" data-respect-dnt="true" data-secure-code="zVbBQs" src="https://static.etracker.com/code/e.js"></script><script async="" type="text/javascript" charset="UTF-8" id="_etCode" src="https://code.etracker.com/t.js?v=4f388f&amp;et=zVbBQs"></script> <noscript> <link rel="stylesheet" media="all" href="//www.etracker.de/cnt_css.php?et=zVbBQs&amp;v=4.0&amp;java=n&amp;et_easy=0&amp;et_pagename=DE%2FService%2FSuche%2Fsuche&amp;et_areas=FDB%2FDE%2FService%2FSuche%2F&amp;et_url=https%3A%2F%2Fwww.foerderdatenbank.de%2FFDB%2FDE%2FService%2FSuche%2Fsuche.html&amp;et_lpage=&amp;et_sub="/> </noscript> <noscript> <link rel="stylesheet" media="all" href="https://www.etracker.de/cntcc?et=$eTrackerKey&amp;v=4.0&amp;java=n&amp;cc_attrs=%7B%27etcc_cu%27%3A%27onsite%27%2C%27etcc_med_onsite%27%3A%27Interne+Suche%27%2C%27etcc_cmp_onsite%27%3A%27Mit+Ergebnis%27%2C%27etcc_st_onsite%27%3A%27%27%7D}"/> </noscript> </head> <body class="body" data-nn="bd101467-e52a-4850-931d-5e2a691629e5-e53dafe5-ee69-40ba-8612-f85921482569" data-svg-sprite="FDB/WS/svg-sprite/data.svg"> <div class="skipLinks"> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?queryResultId=null&amp;pageNo=0&amp;submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport#content">Inhalt</a> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?queryResultId=null&amp;pageNo=0&amp;submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport#navPrimary">Hauptmenu</a> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?queryResultId=null&amp;pageNo=0&amp;submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport#search">Suche</a> </div> <header class="header"> <ul class="ul--meta"> <li class="li--meta"> <a class="link--meta" href="https://www.foerderdatenbank.de/FDB/DE/Service/Kontakt/kontakt.html"> <span class="link--label">Kontakt</span> </a> </li> <li class="li--meta"> <a href="https://www.foerderdatenbank.de/FDB/DE/Service/Merkzettel/merkzettel.html" class="link--meta link--session" aria-label="Number of saved itens" data-basket="FDB/WS/merkzettel/navnode.html"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-hidden="true"> <use xlink:href="#svg__icon-pin"></use> </svg> <span class="link--label"></span> </a> </li> </ul> <a class="header--first-logo" aria-label="Zur Homepage des BMWK" href="http://www.bmwk.de/" target="_blank" rel="noopener noreferrer"> <svg class="icon icon--svg" width="167" height="83" focusable="false" aria-hidden="true"> <use xlink:href="#svg__logo-bmwi-de"></use> </svg> <noscript><img src="SiteGlobals/Frontend/SVG/svg__logo-bmwi-de?view=renderSVG" alt="Logo BMWK"></noscript> </a> <a href="https://www.foerderdatenbank.de/FDB/DE/Home/home.html" class="header--second-logo" aria-label="Zur Startseite"> <svg class="icon icon--svg" width="167" height="83" focusable="false" aria-hidden="true"> <use xlink:href="#svg__logo-fdb-de"></use> </svg> <noscript><img src="SiteGlobals/FDB/Frontend/SVG/svg__logo-fdb-de?view=renderSVG" alt="Logo Förderdatenbank"></noscript> </a> </header> <nav class="nav nav--main"> <a href="javascript:void(0)" role="button" aria-label="Hauptnavigation öffnen" aria-expanded="false" class="opener--mobile mobile--accordion-opener" data-expanded="false" data-scroll="false"> <span></span> </a> <ul class="ul--first-level" style="display: none;"> <li class="li--first-level"> <a href="https://www.foerderdatenbank.de/FDB/DE/Home/home.html" class="nav__link" aria-label="Zur Startseite"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-home"></use> </svg> </a> </li> <li class="li--first-level"> <a href="https://www.foerderdatenbank.de/FDB/DE/Foerderprogramme/foerderprogramme.html" class="li--link"><span class="link--label">Förderprogramme</span></a> </li> <li class="li--first-level"> <a href="https://www.foerderdatenbank.de/FDB/DE/Foerderorganisation/foerderorganisationen.html" class="li--link"><span class="link--label">Förderorganisationen</span></a> </li> <li class="li--first-level"> <a href="https://www.foerderdatenbank.de/FDB/DE/Service/Aktuelles/aktuelles.html" class="li--link"><span class="link--label">Aktuelles</span></a> </li> <li class="li--first-level mainnav--search"> <form name="searchService" action="SiteGlobals/FDB/Forms/Suche/Servicesuche_Formular.html" method="get" enctype="application/x-www-form-urlencoded"> <input type="hidden" name="resourceId" value="75957770-36ec-4a46-a24b-63087e1d6e7c"> <input type="hidden" name="input_" value="bd101467-e52a-4850-931d-5e2a691629e5"> <input type="hidden" name="pageLocale" value="de"> <div class="mainnav__fieldset"> <input id="f75957770-36ec-4a46-a24b-63087e1d6e7cd95d2f40f-bb1f-415d-b220-fa5d3f0908b3" name="templateQueryString" value="" title="Suchbegriff darf nicht mit ? oder * beginnen" type="text" pattern="^[^*?].*$" class="mainnav__input-text" placeholder="Suche" size="26" maxlength="100" data-autosuggest="SiteGlobals/FDB/Forms/Suche/Servicesuche_Autosuggest_Formular.json?userQuery=" autocomplete="off"> <div class="autosuggest-container"><div class="autocomplete-suggestions" style="position: absolute; display: none; max-height: 300px; z-index: 9999;"></div></div> <button type="submit" name="submit" value="Suchen" class="btn mainnav__btn" aria-label="Suche starten"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-hidden="true"> <use xlink:href="#svg__icon-search"></use> </svg> </button> </div> </form> </li> </ul> </nav> <main class="main"> <div class="jumbotron"> <div class="container container--headline"> <div class="content"> <h1 class="title">Fördersuche</h1> <div class="rich--text"> <p> Sie sind auf der Suche nach finanzieller Unterstützung, dem passenden Ansprechpartner oder weiterführenden Informationen zum Thema Förderung und Finanzierung? Geben Sie Ihren Suchbegriff ein und nutzen Sie die Ergebnisfilter.<strong></strong></p> </div> </div> </div> </div> <div class="jumbotron"> <div class="container"> <form name="searchExpert" action="SiteGlobals/FDB/Forms/Suche/Expertensuche_Formular.html" method="get" enctype="application/x-www-form-urlencoded"> <input type="hidden" name="resourceId" value="c4b4dbf3-4c29-4e70-9465-1f1783a8f117"> <input type="hidden" name="input_" value="bd101467-e52a-4850-931d-5e2a691629e5"> <input type="hidden" name="pageLocale" value="de"> <fieldset> <div class="checkboxes__container--search"> <legend class="checkboxes__legend--search"> Sie suchen </legend> <input class="checkboxes__checkbox--search" type="checkbox" id="fc4b4dbf3-4c29-4e70-9465-1f1783a8f117g372ca7b4-2882-4204-8c6c-0b7818258ffbd45e53097-b090-48d9-bf1b-27cdeaef4b7ci1" name="filterCategories" value="FundingProgram" title="Förderprogramm" checked="checked"> <label for="fc4b4dbf3-4c29-4e70-9465-1f1783a8f117g372ca7b4-2882-4204-8c6c-0b7818258ffbd45e53097-b090-48d9-bf1b-27cdeaef4b7ci1" class="checkboxes__label--search"> <svg class="icon icon--svg" width="16" height="16" focusable="false"> <use xlink:href="#svg__icon-tick"></use> </svg> Förderprogramm </label> <input class="checkboxes__checkbox--search" type="checkbox" id="fc4b4dbf3-4c29-4e70-9465-1f1783a8f117g372ca7b4-2882-4204-8c6c-0b7818258ffbdace84b04-84d1-40b5-8d5f-542c49ab24fai2" name="filterCategories" value="FundingOrganisation" title="Förderorganisation"> <label for="fc4b4dbf3-4c29-4e70-9465-1f1783a8f117g372ca7b4-2882-4204-8c6c-0b7818258ffbdace84b04-84d1-40b5-8d5f-542c49ab24fai2" class="checkboxes__label--search"> <svg class="icon icon--svg" width="16" height="16" focusable="false"> <use xlink:href="#svg__icon-tick"></use> </svg> Förderorganisation </label> <input class="checkboxes__checkbox--search" type="checkbox" id="fc4b4dbf3-4c29-4e70-9465-1f1783a8f117g372ca7b4-2882-4204-8c6c-0b7818258ffbd3a647896-142e-4ac3-9ff4-2d0fce90bd9di3" name="filterCategories" value="in_den_weiteren_inhalten" title="In den weiteren Inhalten"> <label for="fc4b4dbf3-4c29-4e70-9465-1f1783a8f117g372ca7b4-2882-4204-8c6c-0b7818258ffbd3a647896-142e-4ac3-9ff4-2d0fce90bd9di3" class="checkboxes__label--search"> <svg class="icon icon--svg" width="16" height="16" focusable="false"> <use xlink:href="#svg__icon-tick"></use> </svg> In den weiteren Inhalten </label> <input type="hidden" name="filterCategories.GROUP" value="1"> </div> </fieldset> <fieldset class="fieldset"> <div class="input__container--search"> <label for="fc4b4dbf3-4c29-4e70-9465-1f1783a8f117df23bf997-5a53-4e73-bba6-74e34245ee2f" class="label--search"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-hidden="true"> <use xlink:href="#svg__icon-search"></use> </svg> </label> <input id="fc4b4dbf3-4c29-4e70-9465-1f1783a8f117df23bf997-5a53-4e73-bba6-74e34245ee2f" name="templateQueryString" value="" title="Suchbegriff darf nicht mit ? oder * beginnen" type="text" pattern="^[^*?].*$" class="input--search" placeholder="Bitte Suchbegriff eingeben" size="26" maxlength="100" data-autosuggest="SiteGlobals/FDB/Forms/Suche/Servicesuche_Autosuggest_Formular.json?userQuery=" autocomplete="off"> <div class="autosuggest-container"><div class="autocomplete-suggestions" style="position: absolute; display: none; max-height: 300px; z-index: 9999;"></div></div> <button type="submit" name="submit" value="Suchen" class="btn btn--search" aria-label="Suche starten"> Suchen </button> <p class="filter--note"> <strong>Hinweis:</strong> für eine erweiterte Suche mit Filtermöglichkeiten bestätigen Sie den “Such-Button” </p> </div> </fieldset> </form> </div> </div> <div class="container content--main content--search for-aside-left"> <div class="content"> <div class="search--hits"> <span id="hits--count">0</span> <span>Beiträge</span> </div> <div class="searchresult"> <div class="card card--horizontal card--fundingprogram"> <p class="card--topline">Förderprogramm</p> <div class="li--meta"> <a class="btn btn--basket" data-basket-id="bf594a43-0ab1-4f77-a439-af3dd6129d92" data-basket-action="add" data-href="FDB/WS/merkzettel/updatenavnode.html" title="Förderprogramm &quot;Umsetzung digitaler Masterplan Kultur&quot; dem Merkzettel hinzufügen." onmousedown="ET_Event.eventStart('Merkzettel', '/BMWI/FDB/Content/DE/Foerderprogramm/Land/Schleswig-Holstein/umsetzung-digitaler-masterplan-kultur', 'merken', 'updatenavnode (70057dd5-6b2d-4c7b-86d3-0806054c24a5)')" target="_blank" rel="noopener noreferrer"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-hidden="true"> <use class="default" xlink:href="#svg__icon-pin"></use> <use class="to-save" xlink:href="#svg__icon-plus"></use> <use class="saved" xlink:href="#svg__icon-tick"></use> <use class="remove" xlink:href="#svg__icon-close"></use> </svg> </a> </div> <p class="card--title"> <a class="" title="Öffnet die Einzelsicht" href="https://www.foerderdatenbank.de/FDB/Content/DE/Foerderprogramm/Land/Schleswig-Holstein/umsetzung-digitaler-masterplan-kultur.html"> <span class="link--label"> Umsetzung digitaler Masterplan Kultur </span> </a> </p> <dl class="grid-modul--two-elements document-info-fundingprogram"> <dt> Wer wird gefördert?: </dt> <dd> Öffentliche Einrichtung, Verband/Vereinigung, Bildungseinrichtung </dd> <dt> Was wird gefördert?: </dt> <dd> Smart Cities &amp; Regionen, Kultur, Medien &amp; Sport, Infrastruktur, Digitalisierung </dd> </dl> </div> </div> </div> <div class="sort--links"> <div class="box"> <h3 class="sort--accordion-opener" data-expanded="false" data-scroll="false" tabindex="0"> <svg class="icon icon--svg" width="16" height="16" focusable="false"> <use xlink:href="#svg__icon-plus"></use> </svg> <span class="btn--label">Sortierung</span></h3> <ul style="display: none;"> <li> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport&amp;sortOrder=title_text_sort+asc" rel="nofollow" title="AufsteigendSortieren" class="sortUp button"><span class="link--label">Titel</span></a> </li> <li> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport&amp;sortOrder=dateOfIssue_dt+desc" rel="nofollow" title="AbsteigendSortieren" class="sortDown button"><span class="link--label">Datum</span></a> </li> </ul> </div> </div> <aside class="sidebar"> <div class="sidebar--tabs"> <h3>Suchergebnisse filtern</h3> <button class="sidebar--accordion-opener" data-expanded="false" tabindex="0"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-plus"></use> </svg> <span class="btn--label">Fördergebiet</span> </button> <ul class="sidebar--ul" style="display: none;"> <li class="sidebar--li"> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?cl2Processes_Foerdergebiet=schleswig_holstein&amp;submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport" rel="nofollow" class="sidebar--link" role="checkbox" aria-checked="false"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-tick"></use> </svg> <span class="link--label">Schleswig-Holstein</span> <span class="link--count">(1)</span> </a> </li> </ul> <button class="sidebar--accordion-opener" data-expanded="false" tabindex="0"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-plus"></use> </svg> <span class="btn--label">GRW-Förderprogramme</span> </button> <ul class="sidebar--ul" style="display: none;"> <li class="sidebar--li"> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_GRW=keine_grw_foerderung&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport" rel="nofollow" class="sidebar--link" role="checkbox" aria-checked="false"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-tick"></use> </svg> <span class="link--label">Keine GRW-Förderprogramme</span> <span class="link--count">(1)</span> </a> </li> </ul> <button class="sidebar--accordion-opener" data-expanded="false" tabindex="0"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-plus"></use> </svg> <span class="btn--label">Förderbereich</span> </button> <ul class="sidebar--ul" style="display: none;"> <li class="sidebar--li"> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport+digitalisierung" rel="nofollow" class="sidebar--link" role="checkbox" aria-checked="false"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-tick"></use> </svg> <span class="link--label">Digitalisierung</span> <span class="link--count">(1)</span> </a> </li> <li class="sidebar--li"> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport+infrastruktur" rel="nofollow" class="sidebar--link" role="checkbox" aria-checked="false"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-tick"></use> </svg> <span class="link--label">Infrastruktur</span> <span class="link--count">(1)</span> </a> </li> <li class="sidebar--li"> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen" rel="nofollow" class="sidebar--link selected" role="checkbox" aria-checked="true"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-tick"></use> </svg> <span class="link--label">Kultur, Medien &amp; Sport</span> <span class="link--count">(1)</span> </a> </li> <li class="sidebar--li"> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=kultur_medien_sport" rel="nofollow" class="sidebar--link selected" role="checkbox" aria-checked="true"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-tick"></use> </svg> <span class="link--label">Smart Cities &amp; Regionen</span> <span class="link--count">(1)</span> </a> </li> <li class="link showall"><a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?submit=Suchen&amp;filterCategories=FundingProgram">Alle Ergebnisse zeigen</a></li> </ul> <a class="btn btn--filter-footer" href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-close"></use> </svg> <span class="btn-label">Kultur, Medien &amp; Sport</span> <span class="count"> (1)</span> </a> <a class="btn btn--filter-footer" href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=kultur_medien_sport"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-close"></use> </svg> <span class="btn-label">Smart Cities &amp; Regionen</span> <span class="count"> (1)</span> </a> &nbsp; <button class="sidebar--accordion-opener expanded" data-expanded="true" tabindex="0"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-minus"></use> </svg> <span class="btn--label">Unterbereich Kultur, Medien &amp; Sport</span> </button> <ul class="sidebar--ul"> <li class="sidebar--li"> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport&amp;cl2Satisfaction_UFKulturMedienSport=kunst_kultur" rel="nofollow" class="sidebar--link" role="checkbox" aria-checked="false"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-tick"></use> </svg> <span class="link--label">Kunst &amp; Kultur</span> <span class="link--count">(1)</span> </a> </li> <li class="sidebar--li"> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport&amp;cl2Satisfaction_UFKulturMedienSport=politische_bildung" rel="nofollow" class="sidebar--link" role="checkbox" aria-checked="false"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-tick"></use> </svg> <span class="link--label">Politische Bildung</span> <span class="link--count">(1)</span> </a> </li> </ul> <button class="sidebar--accordion-opener" data-expanded="false" tabindex="0"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-plus"></use> </svg> <span class="btn--label">Förderberechtigte</span> </button> <ul class="sidebar--ul" style="display: none;"> <li class="sidebar--li"> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?submit=Suchen&amp;cl2Processes_Foerderberechtigte=bildungseinrichtung&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport" rel="nofollow" class="sidebar--link" role="checkbox" aria-checked="false"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-tick"></use> </svg> <span class="link--label">Bildungseinrichtung</span> <span class="link--count">(1)</span> </a> </li> <li class="sidebar--li"> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?submit=Suchen&amp;cl2Processes_Foerderberechtigte=oeffentliche_einrichtung&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport" rel="nofollow" class="sidebar--link" role="checkbox" aria-checked="false"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-tick"></use> </svg> <span class="link--label">Öffentliche Einrichtung</span> <span class="link--count">(1)</span> </a> </li> <li class="sidebar--li"> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?submit=Suchen&amp;cl2Processes_Foerderberechtigte=verband_vereinigung&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport" rel="nofollow" class="sidebar--link" role="checkbox" aria-checked="false"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-tick"></use> </svg> <span class="link--label">Verband/Vereinigung</span> <span class="link--count">(1)</span> </a> </li> </ul> <button class="sidebar--accordion-opener" data-expanded="false" tabindex="0"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-plus"></use> </svg> <span class="btn--label">Förderart</span> </button> <ul class="sidebar--ul" style="display: none;"> <li class="sidebar--li"> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?cl2Processes_Foerderart=zuschuss&amp;submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport" rel="nofollow" class="sidebar--link" role="checkbox" aria-checked="false"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-tick"></use> </svg> <span class="link--label">Zuschuss</span> <span class="link--count">(1)</span> </a> </li> </ul> <button class="sidebar--accordion-opener" data-expanded="false" tabindex="0"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-plus"></use> </svg> <span class="btn--label">Fördergeber</span> </button> <ul class="sidebar--ul" style="display: none;"> <li class="sidebar--li"> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport&amp;cl2Processes_Foerdergeber=land" rel="nofollow" class="sidebar--link" role="checkbox" aria-checked="false"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-tick"></use> </svg> <span class="link--label">Land</span> <span class="link--count">(1)</span> </a> </li> </ul> <button class="sidebar--accordion-opener" data-expanded="false" tabindex="0"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-plus"></use> </svg> <span class="btn--label">Format</span> </button> <ul class="sidebar--ul" style="display: none;"> <li class="sidebar--li"> <a href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?submit=Suchen&amp;filterCategories=FundingProgram&amp;documentType_str=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport" rel="nofollow" class="sidebar--link" role="checkbox" aria-checked="false"> <svg class="icon icon--svg" width="16" height="16" focusable="false" aria-label="label"> <use xlink:href="#svg__icon-tick"></use> </svg> <span class="link--label">Förderprogramm</span> <span class="link--count">(1)</span> </a> </li> </ul> </div></aside> </div> <a class="link--service-opener"><span>Service</span></a> </main> <footer class="footer"> <nav class="nav nav--footer"> <ul class="ul--footer"> <li class="li--footer"> <a class="link--footer link--footer-ministerium" title="Startseite des Bundesministeriums für Wirtschaft und Klimaschutz - Öffnet neues Fenster" href="https://www.bmwk.de/" target="_blank" rel="noopener noreferrer"> <span class="link--label">© 2022 www.bmwk.de</span> </a> </li> </ul> <ul class="ul--footer"> <li class="li--footer"> <a href="https://www.foerderdatenbank.de/FDB/DE/Service/RSS/rss.html" class="link--footer"> <span class="link--label">RSS</span> </a> </li> <li class="li--footer"> <a href="https://www.foerderdatenbank.de/FDB/DE/Meta/Benutzerhinweise/benutzerhinweise.html" class="link--footer"> <span class="link--label">Benutzerhinweise</span> </a> </li> <li class="li--footer"> <a href="https://www.foerderdatenbank.de/FDB/DE/Meta/Inhaltsverzeichnis/inhaltsverzeichnis.html" class="link--footer"> <span class="link--label">Inhaltsverzeichnis</span> </a> </li> <li class="li--footer"> <a href="https://www.foerderdatenbank.de/FDB/DE/Meta/Impressum/impressum.html" class="link--footer"> <span class="link--label">Impressum</span> </a> </li> <li class="li--footer"> <a href="https://www.foerderdatenbank.de/FDB/DE/Meta/Barrierefreiheit/barrierefreiheit.html" class="link--footer"> <span class="link--label">Barrierefreiheit</span> </a> </li> <li class="li--footer"> <a href="https://www.foerderdatenbank.de/FDB/DE/Meta/Datenschutz/datenschutz.html" class="link--footer"> <span class="link--label">Datenschutz</span> </a> </li> </ul> </nav> <div class="to-top"> <a class="link uplink" href="https://www.foerderdatenbank.de/SiteGlobals/FDB/Forms/Suche/Foederprogrammsuche_Formular.html?queryResultId=null&amp;pageNo=0&amp;submit=Suchen&amp;filterCategories=FundingProgram&amp;cl2Processes_Foerderbereich=smart_cities_regionen+kultur_medien_sport#Start" aria-label="NachObenTitle"> <svg class="icon icon--svg" width="16" height="16" focusable="false"> <use xlink:href="#svg__icon-to-top"></use> </svg> </a> </div> </footer> <div class="service--layer"> <div class="service--highlight"><span>Service</span></div> <a href="javascript:void(0)" class="link--service-close" aria-label="Schließen"> <svg class="icon icon--svg" width="16" height="16" focusable="false"> <use xlink:href="#svg__icon-close"></use> </svg> </a> <h2 class="service--title">Wie können wir Ihnen helfen?</h2> <ul class="service--ul"> <li class="service--li"> <svg class="icon icon--svg" width="16" height="16" focusable="false"> <use xlink:href="#svg__icon-arrow-right"></use> </svg> <p class="service--text">Haben Sie Anregungen oder Fragen?</p> <a href="https://www.foerderdatenbank.de/FDB/DE/Service/Kontakt/kontakt.html" class="service--link"> <span class="link--label">Nutzen Sie das&nbsp;<strong>Kontaktformular</strong></span> </a> </li> <li class="service--li"> <svg class="icon icon--svg" width="16" height="16" focusable="false"> <use xlink:href="#svg__icon-arrow-right"></use> </svg> <p class="service--text">Sie haben allgemeine Fragen?</p> <a href="https://www.foerderdatenbank.de/FDB/DE/Service/FAQ/faq.html" class="service--link"> <span class="link--label">Schauen Sie in&nbsp;<strong>Häufige Fragen</strong></span> </a> </li> <li class="service--li"> <svg class="icon icon--svg" width="16" height="16" focusable="false"> <use xlink:href="#svg__icon-arrow-right"></use> </svg> <p class="service--text">Sie haben inhaltliche Fragen?</p> <a href="https://www.foerderdatenbank.de/FDB/DE/Service/Beratung/beratung.html" class="service--link"> <span class="link--label">Hier finden Sie eine Übersicht zu&nbsp;<strong>Beratungsangeboten</strong></span> </a> </li> <li class="service--li"> <svg class="icon icon--svg" width="16" height="16" focusable="false"> <use xlink:href="#svg__icon-arrow-right"></use> </svg> <p class="service--text">An aktuellen Meldungen interessiert?</p> <a href="https://www.foerderdatenbank.de/FDB/DE/Service/RSS/rss.html" class="service--link"> <span class="link--label">Abonnieren Sie den&nbsp;<strong>RSS-Feed</strong></span> </a> </li> <li class="service--li"> <svg class="icon icon--svg" width="16" height="16" focusable="false"> <use xlink:href="#svg__icon-arrow-right"></use> </svg> <p class="service--text">Sie suchen Online-Angebote Ihrer lokalen Behörde?</p> <a href="https://www.behoerdenfinder.de/" class="service--link" target="_blank" rel="noopener noreferrer"> <span class="link--label">Recherchieren Sie im <strong>Behördenfinder Deutschland</strong></span> </a> </li> </ul> </div> <script src="https://www.foerderdatenbank.de/static/FDB/js/main.min.js"></script> <script>var ajax=new XMLHttpRequest();ajax.addEventListener("load",function(){if(this.status<400){var a=document.createElement("div");a.setAttribute("class","svg-sprite");a.innerHTML=this.responseText;document.body.insertBefore(a,document.body.childNodes[0])}});document.body.dataset.svgSprite;ajax.open("GET",document.body.dataset.svgSprite,true);ajax.send();</script>  </body></html>
'''

non_text_tags = ['table', 'ul', 'ol', 'img', 'svg', 'audio', 'video']
non_text_condition = ' or '.join([f'(name() = "{t}")' for t in non_text_tags])
text_condition = 'normalize-space(text()) and not(ancestor::*[normalize-space(text())])'
non_text_ancestor_condition = ' and '.join([f'not(ancestor::{t})' for t in non_text_tags]) 
final_xpath = f'.//*[({text_condition} and {non_text_ancestor_condition}) or {non_text_condition}]'

els = lxmlhtml.fromstring(html).xpath(final_xpath)

# %%
from parsel import Selector

selector = Selector(html)
[i for i in selector.xpath(final_xpath)[0].root]
# Out:
# []
